# %% [markdown]
# # Author : Sumon Singh

# %% [markdown]
# ## Company:
#
# ### The Spark Foundation
#
# ## Job-Role :
#
# ### Data Science And Business Analyst
#
# ## Job-Type :
#
# ### Internship

# %% [markdown]
# ## Task 3 :
#
# ## Exploratory Data Analysis - Retail
#
#
# ### **Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
#
# ### **As a business manager, try to find out the weak areas where you can work to
# ###    make more profit.
#
# ### **What all business problems you can derive by exploring the data?
#
# ### Dataset: https://bit.ly/3i4rbWl

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from jupyterthemes import jtplot
# %matplotlib inline
print('Setup Complete')
# Out:
# Setup Complete

# %% [markdown]
# ## Load Dataset

# %%
df=pd.read_csv('SampleSuperstore.csv')

# %% [markdown]
# ## Analysis  Of Dataset

# %%
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
df.tail(10)
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 9984  Standard Class   Consumer  United States   Long Beach    New York
# 9985  Standard Class   Consumer  United States   Long Beach    New York
# 9986  Standard Class   Consumer  United States  Los Angeles  California
# 9987  Standard Class  Corporate  United States       Athens     Georgia
# 9988  Standard Class  Corporate  United States       Athens     Georgia
# 9989    Second Class   Consumer  United States        Miami     Florida
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9984        11561   East  Office Supplies       Labels   31.500        10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
jtplot.style(context='paper', fscale=1.4, spines=False,ticks=True)
plt.figure(figsize=(25,12))
sns.heatmap(df.corr())
plt.xticks(fontsize=20,fontweight='bold',color='#0ee8cb')
plt.yticks(fontsize=20,fontweight='bold',color='#0ee8cb')
plt.title('Corelation among various data of the dataset',color='blue',fontsize=30,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Corelation among various data of the dataset')

# %%
jtplot.style()
df.hist(color='g')
# Out:
# array([[<AxesSubplot:title={'center':'Postal Code'}>,
#         <AxesSubplot:title={'center':'Sales'}>],
#        [<AxesSubplot:title={'center':'Quantity'}>,
#         <AxesSubplot:title={'center':'Discount'}>],
#        [<AxesSubplot:title={'center':'Profit'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
jtplot.style()
plt.figure(figsize=(15,8))
sns.pairplot(df)

# %% [markdown]
# ### Total Sales based on Region

# %%
df_salesreg_sum=df['Sales'].groupby(df['Region']).sum().sort_values()
df_salesreg_sum
# Out:
# Region
# South      391721.9050
# Central    501239.8908
# East       678781.2400
# West       725457.8245
# Name: Sales, dtype: float64

# %%
jtplot.style(context='paper', fscale=1.4, spines=False,ticks=True, gridlines='-')
plt.figure(figsize=(15,8))
df_salesreg_sum.plot(kind='bar',color='#301e1d')
plt.figlegend(fontsize=25)
plt.xticks(fontsize=20,fontweight='bold',color='#11d124')
plt.yticks(fontsize=20,fontweight='bold',color='#11d124')
plt.title('Total Sales based on Region',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('Region',color='r',fontsize=25,fontweight='bold')
plt.ylabel('Total Sales',color='r',fontsize=25,fontweight='bold')
plt.ylim(0,800000)
# Out:
# (0.0, 800000.0)

# %% [markdown]
# ### Average Sales based on Region

# %%
df_salesreg_avg=df['Sales'].groupby(df['Region']).mean().sort_values()
df_salesreg_avg
# Out:
# Region
# Central    215.772661
# West       226.493233
# East       238.336110
# South      241.803645
# Name: Sales, dtype: float64

# %%
jtplot.style()
plt.figure(figsize=(15,8))
df_salesreg_avg.plot.pie(textprops ={"fontsize":25,'fontweight':'bold','color':'black'},autopct = "%0.2f%%",explode = [0.1,0.1,0.1,0.3],colors=['r','g','y','orange'],shadow=True)
plt.figlegend(fontsize=25)
plt.title('Average Sales based on Region',color='r',fontsize=35,fontweight='bold')
plt.ylabel('Average Sales',color='#0ee819',fontsize=25,fontweight='bold')
# Out:
# Text(0, 0.5, 'Average Sales')

# %% [markdown]
# ### Total Profit based on Region

# %%
df_Region_sum=df['Profit'].groupby(df['Region']).sum().sort_values()
df_Region_sum
# Out:
# Region
# Central     39706.3625
# South       46749.4303
# East        91522.7800
# West       108418.4489
# Name: Profit, dtype: float64

# %%
jtplot.style()
plt.figure(figsize=(15,8))
df_Region_sum.plot(kind='bar',color='b')
plt.figlegend(fontsize=25)
plt.xticks(fontsize=20,fontweight='bold',color='#11d124')
plt.yticks(fontsize=20,fontweight='bold',color='#11d124')
plt.title('Total Profit based on Region',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('Region',color='#ed6b0e',fontsize=25,fontweight='bold')
plt.ylabel('Total Profit',color='#ed6b0e',fontsize=25,fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# ### Average Profit based on Region

# %%
df_Region_avg=df['Profit'].groupby(df['Region']).mean().sort_values()
df_Region_avg
# Out:
# Region
# Central    17.092709
# South      28.857673
# East       32.135808
# West       33.849032
# Name: Profit, dtype: float64

# %%
jtplot.style()
plt.figure(figsize=(15,8))
df_Region_avg.plot.pie(textprops ={"fontsize":25,'fontweight':'bold','color':'black'},autopct = "%0.2f%%",explode = [0.1,0.0,0.1,0.0],colors=['orange','g','lightblue','pink'],shadow=True)
plt.figlegend(fontsize=25)
plt.title('Average Profit based on Region',color='#0eed42',fontsize=35,fontweight='bold')
plt.ylabel('Average Profit',color='r',fontsize=25,fontweight='bold')
# Out:
# Text(0, 0.5, 'Average Profit')

# %% [markdown]
# ### Total Sales based on Ship Mode

# %%
df_salesshi_sum=df['Sales'].groupby(df['Ship Mode']).sum().sort_values()
df_salesshi_sum
# Out:
# Ship Mode
# Same Day          1.283631e+05
# First Class       3.514284e+05
# Second Class      4.591936e+05
# Standard Class    1.358216e+06
# Name: Sales, dtype: float64

# %%
jtplot.style()
plt.figure(figsize=(15,8))
df_salesshi_sum.plot.pie(textprops ={"fontsize":25,'fontweight':'bold','color':'black'},autopct = "%0.2f%%",explode = [0.1,0.1,0.1,0.1],shadow=True)
plt.figlegend(fontsize=15)
plt.title('Total Sales based on Ship Mode',color='#0e46ed',fontsize=35,fontweight='bold')
plt.ylabel('Total Sales',color='yellow',fontsize=25,fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Sales')

# %% [markdown]
# ### Average Sales based on Ship Mode

# %%
df_salesshi_avg=df['Sales'].groupby(df['Ship Mode']).mean().sort_values()
df_salesshi_avg
# Out:
# Ship Mode
# Standard Class    227.583067
# First Class       228.497024
# Second Class      236.089239
# Same Day          236.396179
# Name: Sales, dtype: float64

# %%
jtplot.style()
plt.figure(figsize=(15,8))
df_salesshi_avg.plot.pie(textprops ={"fontsize":25,'fontweight':'bold','color':'black'},autopct = "%0.2f%%",explode = [0.1,0.1,0.1,0.1],colors=['orange','g','lightblue','pink'],shadow=True)
plt.figlegend(fontsize=15)
plt.title('Average Sales based on Ship Mode',color='yellow',fontsize=35,fontweight='bold')
plt.ylabel('Average Sales',color='white',fontsize=25,fontweight='bold')
# Out:
# Text(0, 0.5, 'Average Sales')

# %% [markdown]
# ### Total Profit based on Ship Mode

# %%
df_Shipmode_sum=df['Profit'].groupby(df['Ship Mode']).sum().sort_values()
df_Shipmode_sum
# Out:
# Ship Mode
# Same Day           15891.7589
# First Class        48969.8399
# Second Class       57446.6354
# Standard Class    164088.7875
# Name: Profit, dtype: float64

# %%
jtplot.style(ticks=True)
plt.figure(figsize=(15,8))
df_Shipmode_sum.plot(kind='bar',color='g')
plt.figlegend(fontsize=25)
plt.xticks(fontsize=20,fontweight='bold',color='#11d124')
plt.yticks(fontsize=20,fontweight='bold',color='#11d124')
plt.title('Total Profit based on Shipping mode',color='r',fontsize=35,fontweight='bold')
plt.xlabel('Shipping Mode',color='#aaed0e',fontsize=25,fontweight='bold')
plt.ylabel('Total Profit',color='#aaed0e',fontsize=25,fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# ### Average Profit based on Ship Mode

# %%
df_Shipmode_avg=df['Profit'].groupby(df['Ship Mode']).mean().sort_values()
df_Shipmode_avg
# Out:
# Ship Mode
# Standard Class    27.494770
# Same Day          29.266591
# Second Class      29.535545
# First Class       31.839948
# Name: Profit, dtype: float64

# %%
jtplot.style(ticks=True)
plt.figure(figsize=(15,8))
df_Shipmode_avg.plot(kind='bar',color='brown')
plt.figlegend(fontsize=25)
plt.xticks(fontsize=20,fontweight='bold',color='#11d124')
plt.yticks(fontsize=20,fontweight='bold',color='#11d124')
plt.title('Average Profit based on Shipping Mode',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('Shipping Mode',color='#ed5c0e',fontsize=25,fontweight='bold')
plt.ylabel('Average Profit',color='#ed5c0e',fontsize=25,fontweight='bold')
# Out:
# Text(0, 0.5, 'Average Profit')

# %% [markdown]
# ### Total Sales based on sold goods (Category)

# %%
df_salescat_sum=df['Sales'].groupby(df['Category']).sum().sort_values()
df_salescat_sum
# Out:
# Category
# Office Supplies    719047.0320
# Furniture          741999.7953
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
jtplot.style()
plt.figure(figsize=(15,8))
df_salescat_sum.plot.pie(textprops ={"fontsize":25,'fontweight':'bold','color':'black'},autopct = "%0.2f%%",explode = [0.0,0.1,0.1],colors=['r','g','y'],shadow=True)
plt.figlegend(fontsize=15)
plt.title('Total Sales based on Sold Goods',color='#5b7544',fontsize=35,fontweight='bold')
plt.ylabel('Total Sales',color='#f7071f',fontsize=25,fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Sales')

# %% [markdown]
# ### Average Sales based on sold goods (Category)

# %%
df_salescat_avg=df['Sales'].groupby(df['Category']).mean().sort_values()
df_salescat_avg
# Out:
# Category
# Office Supplies    119.324101
# Furniture          349.834887
# Technology         452.709276
# Name: Sales, dtype: float64

# %%
jtplot.style()
plt.figure(figsize=(15,8))
df_salescat_avg.plot(kind='bar',color='lightblue')
plt.figlegend(fontsize=25)
plt.xticks(fontsize=20,fontweight='bold',color='#11d124')
plt.yticks(fontsize=20,fontweight='bold',color='#11d124')
plt.title('Average Sales based on Sold Goods',color='#6b4f45',fontsize=35,fontweight='bold')
plt.xlabel('Shipping Mode',color='r',fontsize=25,fontweight='bold')
plt.ylabel('Average Sales',color='r',fontsize=25,fontweight='bold')
# Out:
# Text(0, 0.5, 'Average Sales')

# %% [markdown]
# ### Total Profit based on sold goods (Category)

# %%
df_category_sum=df['Profit'].groupby(df['Category']).sum().sort_values()
df_category_sum
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
jtplot.style()
plt.figure(figsize=(15,8))
df_category_sum.plot.pie(textprops ={"fontsize":25,'fontweight':'bold','Color':'black'},autopct = "%0.2f%%",explode = [0.1,0.1,0.1],colors=['r','y','b'],shadow=True)
plt.figlegend(fontsize=15)
plt.title('Total Profit based on Sold Goods',color='#528764',fontsize=35,fontweight='bold')
plt.ylabel('Total Profit',color='blue',fontsize=25,fontweight='bold')
# Out:
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\core.py:1547: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   results = ax.pie(y, labels=blabels, **kwds)
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# ### Average Profit based on sold goods (Category)

# %%
df_category_avg=df['Profit'].groupby(df['Category']).mean().sort_values()
df_category_avg
# Out:
# Category
# Furniture           8.699327
# Office Supplies    20.327050
# Technology         78.752002
# Name: Profit, dtype: float64

# %%
jtplot.style()
plt.figure(figsize=(15,8))
df_category_avg.plot.pie(textprops ={"fontsize":25,'fontweight':'bold','color':'black'},autopct = "%0.2f%%",explode = [0.1,0.1,0.1],colors=['#03a1fc','#b37120','#ba2d4b'],shadow=True)
plt.figlegend(fontsize=15)
plt.title('Average Profit based on Sold Goods',color='darkblue',fontsize=35,fontweight='bold')
plt.ylabel('Average Profit',color='r',fontsize=25,fontweight='bold')
# Out:
# Text(0, 0.5, 'Average Profit')

# %% [markdown]
# ### Total Sales based on each state

# %%
df_state_sales_sum=df['Sales'].groupby(df['State']).sum().sort_values()
df_state_sales_sum
# Out:
# State
# North Dakota               919.9100
# West Virginia             1209.8240
# Maine                     1270.5300
# South Dakota              1315.5600
# Wyoming                   1603.1360
# District of Columbia      2865.0200
# Kansas                    2914.3100
# Idaho                     4382.4860
# Iowa                      4579.7600
# New Mexico                4783.5220
# Montana                   5589.3520
# New Hampshire             7292.5240
# Nebraska                  7464.9300
# South Carolina            8481.7100
# Vermont                   8929.3700
# Louisiana                 9217.0300
# Mississippi              10771.3400
# Utah                     11220.0560
# Arkansas                 11678.1300
# Connecticut              13384.3570
# Nevada                   16729.1020
# Oregon                   17431.1500
# Alabama                  19510.6400
# Oklahoma                 19683.3900
# Missouri                 22205.1500
# Rhode Island             22627.9560
# ...

# %%
jtplot.style(context='paper', fscale=1.4, spines=False,ticks=True, gridlines='-')
plt.figure(figsize=(20,8))
df_state_sales_sum.plot(kind='bar',color='#445227')
plt.figlegend(fontsize=40)
plt.xticks(fontsize=25,fontweight='bold',color='#11d124')
plt.yticks(fontsize=25,fontweight='bold',color='#11d124')
plt.title('Total Sales based on each States',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('States',color='#1bb9c4',fontsize=35,fontweight='bold')
plt.ylabel('Total Sales',color='#1bb9c4',fontsize=35,fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Sales')

# %% [markdown]
# ### Average Sales based on each State

# %%
df_state_sales_avg=df['Sales'].groupby(df['State']).mean().sort_values()
df_state_sales_avg
# Out:
# State
# South Dakota             109.630000
# Kansas                   121.429583
# New Mexico               129.284378
# North Dakota             131.415714
# Oregon                   140.573790
# Iowa                     152.658667
# Arizona                  157.508933
# Maine                    158.816250
# Illinois                 162.939230
# Connecticut              163.223866
# Ohio                     166.861697
# Tennessee                167.551219
# Texas                    172.779742
# Colorado                 176.418231
# Arkansas                 194.635500
# Nebraska                 196.445526
# Pennsylvania             198.487077
# South Carolina           201.945476
# Mississippi              203.232830
# Idaho                    208.689810
# Utah                     211.699170
# Massachusetts            212.106919
# Louisiana                219.453095
# North Carolina           223.305880
# Maryland                 225.766886
# California               228.729451
# ...

# %%
jtplot.style(ticks=True)
plt.figure(figsize=(20,8))
df_state_sales_avg.plot(kind='bar',color='#9c622d')
plt.figlegend(fontsize=25)
plt.xticks(fontsize=20,fontweight='bold',color='#11d124')
plt.yticks(fontsize=20,fontweight='bold',color='#11d124')
plt.title('Average Sales based on each States',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('States',color='r',fontsize=35,fontweight='bold')
plt.ylabel('Average Sales',color='r',fontsize=35,fontweight='bold')
# Out:
# Text(0, 0.5, 'Average Sales')

# %% [markdown]
# ### Total Profit based on each State

# %%
df_state_sum=df['Profit'].groupby(df['State']).sum().sort_values()
df_state_sum
# Out:
# State
# Texas                  -25729.3563
# Ohio                   -16971.3766
# Pennsylvania           -15559.9603
# Illinois               -12607.8870
# North Carolina          -7490.9122
# Colorado                -6527.8579
# Tennessee               -5341.6936
# Arizona                 -3427.9246
# Florida                 -3399.3017
# Oregon                  -1190.4705
# Wyoming                   100.1960
# West Virginia             185.9216
# North Dakota              230.1497
# South Dakota              394.8283
# Maine                     454.4862
# Idaho                     826.7231
# Kansas                    836.4435
# District of Columbia     1059.5893
# New Mexico               1157.1161
# Iowa                     1183.8119
# New Hampshire            1706.5028
# South Carolina           1769.0566
# Montana                  1833.3285
# Nebraska                 2037.0942
# Louisiana                2196.1023
# Vermont                  2244.9783
# ...

# %%
jtplot.style(ticks=True)
plt.figure(figsize=(20,8))
df_state_sum.plot(kind='bar',color='#0b97e3')
plt.figlegend(fontsize=25)
plt.xticks(fontsize=20,fontweight='bold',color='#11d124')
plt.yticks(fontsize=20,fontweight='bold',color='#11d124')
plt.title('Total Profit based on each States',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('States',color='r',fontsize=35,fontweight='bold')
plt.ylabel('Total Profit',color='r',fontsize=35,fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# ### Average Profit based on each State

# %%
df_state_avg=df['Profit'].groupby(df['State']).mean().sort_values()
df_state_avg
# Out:
# State
# Ohio                    -36.186304
# Colorado                -35.867351
# North Carolina          -30.083985
# Tennessee               -29.189583
# Pennsylvania            -26.507598
# Texas                   -26.121174
# Illinois                -25.625787
# Arizona                 -15.303235
# Oregon                   -9.600569
# Florida                  -8.875461
# New Mexico               31.273408
# North Dakota             32.878529
# South Dakota             32.902358
# Kansas                   34.851813
# California               38.171608
# Idaho                    39.367767
# Iowa                     39.460397
# South Carolina           42.120395
# Connecticut              42.823071
# West Virginia            46.480400
# Utah                     48.047802
# Massachusetts            50.262975
# Louisiana                52.288150
# Nebraska                 53.607742
# Maine                    56.810775
# Mississippi              59.867475
# ...

# %%
jtplot.style()
plt.figure(figsize=(20,8))
df_state_avg.plot(kind='bar',color='#a8328b')
plt.figlegend(fontsize=25)
plt.xticks(fontsize=20,fontweight='bold',color='#11d124')
plt.yticks(fontsize=20,fontweight='bold',color='#11d124')
plt.title('Average Profit based on each States',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('States',color='r',fontsize=35,fontweight='bold')
plt.ylabel('Average Profit',color='r',fontsize=35,fontweight='bold')
# Out:
# Text(0, 0.5, 'Average Profit')

# %% [markdown]
# ### Total Sales based on sold goods (Sub-Category)

# %%
df_salessubcat_sum=df['Sales'].groupby(df['Sub-Category']).sum().sort_values()
df_salessubcat_sum
# Out:
# Sub-Category
# Fasteners        3024.2800
# Labels          12486.3120
# Envelopes       16476.4020
# Art             27118.7920
# Supplies        46673.5380
# Paper           78479.2060
# Furnishings     91705.1640
# Appliances     107532.1610
# Bookcases      114879.9963
# Copiers        149528.0300
# Accessories    167380.3180
# Machines       189238.6310
# Binders        203412.7330
# Tables         206965.5320
# Storage        223843.6080
# Chairs         328449.1030
# Phones         330007.0540
# Name: Sales, dtype: float64

# %%
jtplot.style(ticks=True)
plt.figure(figsize=(25,12))
df_salessubcat_sum.plot(kind='bar',color='#43db21')
plt.figlegend(fontsize=25)
plt.xticks(fontsize=20,fontweight='bold',color='#11d124')
plt.yticks(fontsize=20,fontweight='bold',color='#11d124')
plt.title('Total Sales based on Sub-Catagory',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('Sub-Catagory',color='r',fontsize=35,fontweight='bold')
plt.ylabel('Total Sales',color='r',fontsize=35,fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Sales')

# %% [markdown]
# ### Average Sales based on sold goods (Sub-Category)

# %%
df_salessubcat_avg=df['Sales'].groupby(df['Sub-Category']).mean().sort_values()
df_salessubcat_avg
# Out:
# Sub-Category
# Fasteners        13.936774
# Art              34.068834
# Labels           34.303055
# Paper            57.284092
# Envelopes        64.867724
# Furnishings      95.825668
# Binders         133.560560
# Accessories     215.974604
# Appliances      230.755710
# Supplies        245.650200
# Storage         264.590553
# Phones          371.211534
# Bookcases       503.859633
# Chairs          532.332420
# Tables          648.794771
# Machines       1645.553313
# Copiers        2198.941618
# Name: Sales, dtype: float64

# %%
jtplot.style(ticks=True)
plt.figure(figsize=(25,12))
df_salessubcat_avg.plot(kind='bar',color='#91405a')
plt.figlegend(fontsize=25)
plt.xticks(fontsize=20,fontweight='bold',color='#11d124')
plt.yticks(fontsize=20,fontweight='bold',color='#11d124')
plt.title('Average Sales based on Sub-Catagory',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('Sub-Catagory',color='r',fontsize=35,fontweight='bold')
plt.ylabel('Average Sales',color='r',fontsize=35,fontweight='bold')
# Out:
# Text(0, 0.5, 'Average Sales')

# %% [markdown]
# ### Total Profit based on sold goods (Sub-Category)

# %%
df_subcat_sum=df['Profit'].groupby(df['Sub-Category']).sum().sort_values()
df_subcat_sum
# Out:
# Sub-Category
# Tables        -17725.4811
# Bookcases      -3472.5560
# Supplies       -1189.0995
# Fasteners        949.5182
# Machines        3384.7569
# Labels          5546.2540
# Art             6527.7870
# Envelopes       6964.1767
# Furnishings    13059.1436
# Appliances     18138.0054
# Storage        21278.8264
# Chairs         26590.1663
# Binders        30221.7633
# Paper          34053.5693
# Accessories    41936.6357
# Phones         44515.7306
# Copiers        55617.8249
# Name: Profit, dtype: float64

# %%
jtplot.style(ticks=True)
plt.figure(figsize=(25,12))
df_subcat_sum.plot(kind='bar',color='#4c6949')
plt.figlegend(fontsize=25)
plt.xticks(fontsize=20,fontweight='bold',color='#11d124')
plt.yticks(fontsize=20,fontweight='bold',color='#11d124')
plt.title('Total Profit based on Sub-Catagory',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('Sub-Catagory',color='r',fontsize=35,fontweight='bold')
plt.ylabel('Total Profit',color='r',fontsize=35,fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# ### Average Profit based on sold goods (Sub-Category)

# %%
df_subcat_avg=df['Profit'].groupby(df['Sub-Category']).mean().sort_values()
df_subcat_avg
# Out:
# Sub-Category
# Tables         -55.565771
# Bookcases      -15.230509
# Supplies        -6.258418
# Fasteners        4.375660
# Art              8.200737
# Furnishings     13.645918
# Labels          15.236962
# Binders         19.843574
# Paper           24.856620
# Storage         25.152277
# Envelopes       27.418019
# Machines        29.432669
# Appliances      38.922758
# Chairs          43.095894
# Phones          50.073938
# Accessories     54.111788
# Copiers        817.909190
# Name: Profit, dtype: float64

# %%
jtplot.style(ticks=True)
plt.figure(figsize=(25,12))
df_subcat_avg.plot(kind='bar',color='#5876a8')
plt.figlegend(fontsize=25)
plt.xticks(fontsize=20,fontweight='bold',color='#11d124')
plt.yticks(fontsize=20,fontweight='bold',color='#11d124')
plt.title('Average Profit based on Sub-Catagory',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('Sub-Catagory',color='r',fontsize=35,fontweight='bold')
plt.ylabel('Average Profit',color='r',fontsize=35,fontweight='bold')
# Out:
# Text(0, 0.5, 'Average Profit')

# %% [markdown]
# ### Relationship between Discount and Profit

# %%
jtplot.style()
plt.figure(figsize=(15,8))
sns.lineplot(x='Discount',y='Profit',data=df)
plt.xticks(fontsize=20,fontweight='bold')
plt.yticks(fontsize=20,fontweight='bold')
plt.title('Discount VS Profit',color='#1b56c4',fontsize=35,fontweight='bold')
plt.xlabel('Discount',color='r',fontsize=35,fontweight='bold')
plt.ylabel('Profit',color='r',fontsize=35,fontweight='bold')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# ###  Relationship between Discount and sales

# %%
jtplot.style()
plt.figure(figsize=(15,8))
sns.lineplot(x='Discount',y='Sales',data=df,color='r')
plt.xticks(fontsize=20,fontweight='bold')
plt.yticks(fontsize=20,fontweight='bold')
plt.title('Discount VS Sales',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('Discount',color='r',fontsize=35,fontweight='bold')
plt.ylabel('Sales',color='r',fontsize=35,fontweight='bold')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ### Realtion between Sales and Segment

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
jtplot.style()
plt.figure(figsize=(15,8))
sns.lineplot(x='Segment',y='Sales',data=df,color='orange')
plt.xticks(fontsize=20,fontweight='bold')
plt.yticks(fontsize=20,fontweight='bold')
plt.title('Segment VS Sales',color='#e00bb9',fontsize=35,fontweight='bold')
plt.xlabel('Segment',color='r',fontsize=35,fontweight='bold')
plt.ylabel('Sales',color='r',fontsize=35,fontweight='bold')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ### Realtion between Profit and Segment

# %%
jtplot.style()
plt.figure(figsize=(15,8))
sns.lineplot(x='Segment',y='Profit',data=df,color='g')
plt.xticks(fontsize=20,fontweight='bold')
plt.yticks(fontsize=20,fontweight='bold')
plt.title('Segment VS Profit',color='#1b56c4',fontsize=35,fontweight='bold')
plt.xlabel('Segment',color='r',fontsize=35,fontweight='bold')
plt.ylabel('Profit',color='r',fontsize=35,fontweight='bold')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# # Conclusion :

# %% [markdown]
#  ##  A) On total North Dakota has the lowest sales whereas on average south Dakota has the lowest sales
#
#  ## B) On total Texas has the most loses(Profit in negative) whereas on  average Ohlo has the most loses(Profit in negative)
#
#  ## C) Fasteners on average and total in both way has the lowest Sales
#  ## whereas on average and total in both way Tables caused the most loses(Profit in negative)
#
#  ## D) Office supplies has the lowest number of sales both on average and total whereas Furniture sectors caused the most loses
#
#  ## E) On total South region has least number of sales whereas on average Central region has the lowest sales
#
#  ## F) Central region caused least number of profits
#
#  ## G) Consumer has the least number of sales and profits
#
#  ## H) With increasing number of discounts profit decreases
#
#  ##  I) With increasing number of discounts sales is increases but after a certain time sales become very much low

# %% [markdown]
# #  Thank You :)
